# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length

# %%
data=pd.read_fwf("35895-0.txt")

# %%
data
# Out:
#       The Project Gutenberg EBook of The Gospel of Buddha, by Paul Carus
# 0      This eBook is for the use of anyone anywhere a...
# 1      almost no restrictions whatsoever.  You may co...
# 2      re-use it under the terms of the Project Guten...
# 3         with this eBook or online at www.gutenberg.net
# 4                            Title: The Gospel of Buddha
# ...                                                  ...
# 10300                           http://www.gutenberg.net
# 10301  This Web site includes information about Proje...
# 10302  including how to make donations to the Project...
# 10303  Archive Foundation, how to help produce our ne...
# 10304  subscribe to our email newsletter to hear abou...
#
# [10305 rows x 1 columns]

# %%
from docx import Document
from docx.shared import Inches

# %%
document=Document("35895-0.docx")

# %%
document

# %%
dialogue=[]
for i in range(300):
    print(document.paragraphs[i].paragraph_format.left_indent)
    print(document.paragraphs[i].paragraph_format.alignment)
    print(document.paragraphs[i].text)
    print("NEXT VALUE","="*80)

        #print(document.paragraphs[i].text)
        #print("NEXT VALUE")'''
# Out:
# None
# None
# The Project Gutenberg EBook of The Gospel of Buddha, by Paul Carus
# NEXT VALUE ================================================================================
# None
# None
#
# NEXT VALUE ================================================================================
# None
# None
# This eBook is for the use of anyone anywhere at no cost and with
# NEXT VALUE ================================================================================
# None
# None
# almost no restrictions whatsoever.  You may copy it, give it away or
# NEXT VALUE ================================================================================
# None
# None
# re-use it under the terms of the Project Gutenberg License included
# NEXT VALUE ================================================================================
# None
# None
# with this eBook or online at www.gutenberg.net
# NEXT VALUE ================================================================================
# None
# None
#
# ...

# %%
data=pd.read_fwf("Complete_data .txt",ignore_header=True)

# %%
data
# Out:
#                                                     0.1  \
# 0     � 1.The Buddha: "What do you think, Rahula: Wh...
# 1                                                   0.2
# 2     � 2.Once the Blessed One was staying at Kosamb...
# 3                                                   0.3
# 4     � 3."'Stress should be known. The cause by whi...
# ...                                                 ...
# 1174  17:1. For thy judgments, O Lord, are great, an...
# 1175                                               7.18
# 1176  intercession, in the sedition on occasion of C...
# 1177                                               7.19
# 1178  All creatures obey God's orders for the servic...
#
#                                              Unnamed: 1  \
# 0          Rahula delighted in the Blessed One's words.
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
document=Document("Complete_data .docx")

# %%
dialogue=[]
for i in range(300):
    print(document.paragraphs[i].paragraph_format.left_indent)
    #print(document.paragraphs[i].paragraph_format.alignment)
    print(document.paragraphs[i].text)
    print("NEXT VALUE","="*80)

        #print(document.paragraphs[i].text)
        #print("NEXT VALUE")'''
# Out:
# None
# 0.1
# NEXT VALUE ================================================================================
# None
# ...
