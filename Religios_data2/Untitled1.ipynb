# %%
import pandas as pd

# %%
data=pd.read_csv("religion_data.csv")
data.drop(['Unnamed: 0'],axis=1,inplace=True)

data
# Out:
#                                                     text       label
# 0      compiled from ancient records by paul carus in...    buddhism
# 1      rejoice at the glad tidings  the buddha  our l...    buddhism
# 2      root of all evil  he has shown us the way of s...    buddhism
# 3      the buddha dispels the illusions of our mind a...    buddhism
# 4      the buddha  our lord  brings comfort to the we...    buddhism
# ...                                                  ...         ...
# 27093      and the spirit and the bride say  come  an...  christians
# 27094      for i testify unto every man that heareth ...  christians
# 27095  out of the holy city  and from the things whic...  christians
# 27096      he which testifieth these things saith  su...  christians
# 27097      the grace of our lord jesus christ be with...  christians
#
# [27098 rows x 2 columns]

# %%
data.rename(columns={'text':'tweet'},inplace=True)

# %%
data1=pd.read_csv("sample_religion_data.csv")
data1.drop(['Unnamed: 0'],axis=1,inplace=True)
data1
# Out:
#                                                 tweet       label
# 0   I would rather stand with God and be judged by...  christians
# 1   You’ve got voices pulling you in all different...  christians
# 2   Lord we need a generation of believers who are...  christians
# 3   What are you living for? I resolve to give God...  christians
# 4   When all you see is your pain, you lose sight ...  christians
# ..                                                ...         ...
# 72  Gentlemen, you can't fight in here! This is th...      normal
# 73            I don't want to survive. I want to live      normal
# 74                         Elementary, my dear Watson      normal
# 75                        That'll do, pig. That'll do      normal
# 76                      I wish I knew how to quit you      normal
#
# [77 rows x 2 columns]

# %%
s1 = pd.merge(data, data, how='inner', on=['tweet'])
s1
# Out:
#                                                    tweet     label_x  \
# 0      compiled from ancient records by paul carus in...    buddhism
# 1      rejoice at the glad tidings  the buddha  our l...    buddhism
# 2      root of all evil  he has shown us the way of s...    buddhism
# 3      the buddha dispels the illusions of our mind a...    buddhism
# 4      the buddha  our lord  brings comfort to the we...    buddhism
# ...                                                  ...         ...
# 27221      i jesus have sent mine angel to testify un...  christians
# 27222      and the spirit and the bride say  come  an...  christians
# 27223      for i testify unto every man that heareth ...  christians
# 27224  out of the holy city  and from the things whic...  christians
# 27225      he which testifieth these things saith  su...  christians
#
#           label_y
# 0        buddhism
# 1        buddhism
# 2        buddhism
# 3        buddhism
# 4        buddhism
# ...           ...
# 27221  christians
# 27222  christians
# 27223  christians
# 27224  christians
# 27225  christians
#
# [27226 rows x 3 columns]
