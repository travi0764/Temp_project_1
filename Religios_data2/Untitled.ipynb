# %%
import pandas as pd
import numpy as np
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length

# %%
from docx import Document
from docx.shared import Inches

# %%
document=Document("35895-0.docx")

# %%
dialogue=[]
for i in range(300):
    print(document.paragraphs[i].paragraph_format.left_indent)
    print(document.paragraphs[i].paragraph_format.alignment)
    print(document.paragraphs[i].text)
    print("NEXT VALUE","="*80)

        #print(document.paragraphs[i].text)
        #print("NEXT VALUE")'''
# Out:
# None
# None
# Title: The Gospel of Buddha
# NEXT VALUE ================================================================================
# None
# None
# Compiled from Ancient Records by Paul Carus INTRODUCTION.
# NEXT VALUE ================================================================================
# 0
# None
#
# NEXT VALUE ================================================================================
# None
# None
# I.
# NEXT VALUE ================================================================================
# 0
# None
#
# NEXT VALUE ================================================================================
# None
# None
# REJOICE!
# NEXT VALUE ================================================================================
# 0
# None
#
# NEXT VALUE ================================================================================
# None
# None
# Rejoice at the glad tidings! The Buddha, our Lord, has found the
# ...

# %%
def extract_dialogues(document):
    dialogue=[]
    for i in range(len(document.paragraphs)):
        dialogue.append(document.paragraphs[i].text)
    return dialogue

# %%
dialogue=extract_dialogues(document)
c=0
for i in dialogue:
    print(i)
    c+=1
    if c==100:
        break
# Out:
# Title: The Gospel of Buddha
# Compiled from Ancient Records by Paul Carus INTRODUCTION.
#
# I.
#
# REJOICE!
#
# Rejoice at the glad tidings! The Buddha, our Lord, has found the
# root of all evil; he has shown us the way of salvation.	1
# The Buddha dispels the illusions of our mind and redeems us from
# the terror of death.	2
# The Buddha, our Lord, brings comfort to the weary and
# sorrow-laden; he restores peace to those who are broken down under the burden of life. He gives courage to the weak when they
# would fain give up self-reliance and hope.	3
# Ye that suffer from the tribulations of life, ye that have to struggle and endure, ye that yearn for a life of truth, rejoice
# at the glad tidings!	4
# There is balm for the wounded, and there is bread for the hungry. There is water for the thirsty, and there is hope for the despairing. There is light for those in darkness, and there is
# inexhaustible blessing for the upright.	5
# ...

# %%
len(dialogue)
# Out:
# 3110

# %%
for i in dialogue:
    if len(i)<5:
        dialogue.remove(i)

# %%
buddhism=pd.DataFrame(dialogue)
buddhism.head(10)
# Out:
#                                                    0
# 0                        Title: The Gospel of Buddha
# 1  Compiled from Ancient Records by Paul Carus IN...
# 2                                                 I.
# 3                                           REJOICE!
# 4  Rejoice at the glad tidings! The Buddha, our L...
# 5  root of all evil; he has shown us the way of s...
# 6  The Buddha dispels the illusions of our mind a...
# 7                            the terror of death.\t2
# 8  The Buddha, our Lord, brings comfort to the we...
# 9  sorrow-laden; he restores peace to those who a...

# %%
buddhism
# Out:
#                                                       0
# 0                           Title: The Gospel of Buddha
# 1     Compiled from Ancient Records by Paul Carus IN...
# 2                                                    I.
# 3                                              REJOICE!
# 4     Rejoice at the glad tidings! The Buddha, our L...
# ...                                                 ...
# 2455  exist between heaven and earth, great and smal...
# 2456  "My doctrine is like unto the heavens, for the...
# 2457              girls, the powerful and the lowly.\t9
# 2458  "But when I spoke, they knew me not and would ...
# 2459  vanish away. But they knew me not, even when I...
#
# [2460 rows x 1 columns]

# %%
buddhism.rename(columns={0:'text'},inplace=True)
buddhism['label']='buddhism'

# %%
document=Document("pg10.docx")

# %%
dialogue=extract_dialogues(document)
c=0
for i in dialogue:
    print(i)
    c+=1
    if c==100:
        break
# Out:
# The Project Gutenberg EBook of The King James Bible
#
#
# The First Book of Moses:	Called Genesis
#
# 1:1 In the beginning God created the heavens and the earth.
#
# 1:2 And the earth was without form, and void; and darkness was upon the face of the deep. And the Spirit of God moved upon the face of the waters.
#
# 1:3 And God said, Let there be light: and there was light.
#
# 1:4 And God saw the light, that it was good: and God divided the light from the darkness.
#
# 1:5 And God called the light Day, and the darkness he called Night. And the evening and the morning were the first day.
#
# 1:6 And God said, Let there be a firmament in the midst of the waters, and let it divide the waters from the waters.
#
# 1:7 And God made the firmament, and divided the waters which were under the firmament from the waters which were above the firmament: and it was so.
#
# 1:8 And God called the firmament Heaven. And the evening and the morning were the second day.
#
# ...

# %%
len(dialogue)
# Out:
# 50839

# %%
for i in dialogue:
    if len(i)<5:
        dialogue.remove(i)

# %%
christians=pd.DataFrame(dialogue)
christians.head(10)
# Out:
#                                                    0
# 0  The Project Gutenberg EBook of The King James ...
# 1           The First Book of Moses:\tCalled Genesis
# 2  1:1 In the beginning God created the heavens a...
# 3  1:2 And the earth was without form, and void; ...
# 4  1:3 And God said, Let there be light: and ther...
# 5  1:4 And God saw the light, that it was good: a...
# 6  1:5 And God called the light Day, and the dark...
# 7  1:6 And God said, Let there be a firmament in ...
# 8  1:7 And God made the firmament, and divided th...
# 9  1:8 And God called the firmament Heaven. And t...

# %%
christians
# Out:
#                                                        0
# 0      The Project Gutenberg EBook of The King James ...
# 1               The First Book of Moses:\tCalled Genesis
# 2      1:1 In the beginning God created the heavens a...
# 3      1:2 And the earth was without form, and void; ...
# 4      1:3 And God said, Let there be light: and ther...
# ...                                                  ...
# 25650  22:20 He which testifieth these things saith, ...
# 25651
# 25652                         Even so, come, Lord Jesus.
# 25653
# 25654  22:21 The grace of our Lord Jesus Christ be wi...
#
# [25655 rows x 1 columns]

# %%
christians.rename(columns={0:'text'},inplace=True)
christians['label']='christians'

# %%
christians.to_csv('bible.csv')
buddhism.to_csv('bible.csv')

# %%
christians.tail()
# Out:
#                                                     text       label
# 25650  22:20 He which testifieth these things saith, ...  christians
# 25651                                                     christians
# 25652                         Even so, come, Lord Jesus.  christians
# 25653                                                     christians
# 25654  22:21 The grace of our Lord Jesus Christ be wi...  christians

# %%
christians
# Out:
#                                                     text       label
# 0      The Project Gutenberg EBook of The King James ...  christians
# 1               The First Book of Moses:\tCalled Genesis  christians
# 2      1:1 In the beginning God created the heavens a...  christians
# 3      1:2 And the earth was without form, and void; ...  christians
# 4      1:3 And God said, Let there be light: and ther...  christians
# ...                                                  ...         ...
# 25650  22:20 He which testifieth these things saith, ...  christians
# 25651                                                     christians
# 25652                         Even so, come, Lord Jesus.  christians
# 25653                                                     christians
# 25654  22:21 The grace of our Lord Jesus Christ be wi...  christians
#
# [25655 rows x 2 columns]

# %%
document=Document("pg17.docx")

# %%
data=pd.concat([buddhism,christians],ignore_index=True)
data
# Out:
#                                                     text       label
# 0                            Title: The Gospel of Buddha    buddhism
# 1      Compiled from Ancient Records by Paul Carus IN...    buddhism
# 2                                                     I.    buddhism
# 3                                               REJOICE!    buddhism
# 4      Rejoice at the glad tidings! The Buddha, our L...    buddhism
# ...                                                  ...         ...
# 28110  22:20 He which testifieth these things saith, ...  christians
# 28111                                                     christians
# 28112                         Even so, come, Lord Jesus.  christians
# 28113                                                     christians
# 28114  22:21 The grace of our Lord Jesus Christ be wi...  christians
#
# [28115 rows x 2 columns]

# %%
def count_words(text):
    return len(text.split())

# %%
data['word_count'] = data["text"].apply(lambda x:count_words(x))

# %%
data
# Out:
#                                                     text       label  \
# 0                            Title: The Gospel of Buddha    buddhism
# 1      Compiled from Ancient Records by Paul Carus IN...    buddhism
# 2                                                     I.    buddhism
# 3                                               REJOICE!    buddhism
# 4      Rejoice at the glad tidings! The Buddha, our L...    buddhism
# ...                                                  ...         ...
# 28110  22:20 He which testifieth these things saith, ...  christians
# 28111                                                     christians
# 28112                         Even so, come, Lord Jesus.  christians
# 28113                                                     christians
# 28114  22:21 The grace of our Lord Jesus Christ be wi...  christians
#
#        word_count
# 0               5
# 1               8
# 2               1
# 3               1
# 4              12
# ...           ...
# ...

# %%
mask=data['word_count']>5

# %%
data=data.loc[mask]
data
# Out:
#                                                     text       label  \
# 1      Compiled from Ancient Records by Paul Carus IN...    buddhism
# 4      Rejoice at the glad tidings! The Buddha, our L...    buddhism
# 5      root of all evil; he has shown us the way of s...    buddhism
# 6      The Buddha dispels the illusions of our mind a...    buddhism
# 8      The Buddha, our Lord, brings comfort to the we...    buddhism
# ...                                                  ...         ...
# 28105  22:17 And the Spirit and the bride say, Come. ...  christians
# 28107  22:18 For I testify unto every man that hearet...  christians
# 28108  out of the holy city, and from the things whic...  christians
# 28110  22:20 He which testifieth these things saith, ...  christians
# 28114  22:21 The grace of our Lord Jesus Christ be wi...  christians
#
#        word_count
# 1               8
# 4              12
# 5              13
# 6              12
# 8              10
# ...           ...
# ...

# %%
import pandas as pd
import nltk
import re
import string
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
import preprocessor as p
from nltk.stem import WordNetLemmatizer 
from nltk import sent_tokenize
from nltk import word_tokenize

stop_words = stopwords.words()

def cleaning(text):        
    # converting to lowercase, removing URL links, special characters, punctuations...
    
    #using full form in place of abbrevations
    text = re.sub(r"won't", "will not",text)
    text = re.sub(r"can\'t", "can not",text)
    text = re.sub(r"n\'t", " not",text)
    text = re.sub(r"\'re", " are",text)
    text = re.sub(r"\'s", " is",text)
    text = re.sub(r"\'d", " would",text)
    text = re.sub(r"\'ll", " will",text)
    text = re.sub(r"\'t", " not",text)
    text = re.sub(r"\'ve", " have",text)
    text = re.sub(r"\'m", " am",text)
    text = re.sub('RT'," ", text)
    text = re.sub('gt'," ", text)
    text=p.clean(text)
    text = re.sub("\$RESERVED\$ \$MENTION\$|\$NUMBER\$|\$MENTION\$",' ', text)
    text = text.lower()
    text = re.sub('https?://\S+|www\.\S+', ' ', text)
    text = re.sub('<.*?>+', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\n', ' ', text)
    text = re.sub('[’“”…]', ' ', text)   
    
    
    text = re.sub('user'," ", text)
    text = re.sub('url'," ", text)
    
    text = re.sub('reserved'," ", text)
    
    
    
    
    
    
    text = re.sub("[^A-Za-z]",' ',text)
    

    # removing the emojies               
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r' ', text)   
    
    
    
    
    
    
    return text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ravitiwari/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ravitiwari/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data.text=data.text.apply(cleaning)
# Out:
# /Users/ravitiwari/miniforge3/envs/tf/lib/python3.9/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data
# Out:
#                                                     text       label  \
# 1      compiled from ancient records by paul carus in...    buddhism
# 4      rejoice at the glad tidings  the buddha  our l...    buddhism
# 5      root of all evil  he has shown us the way of s...    buddhism
# 6      the buddha dispels the illusions of our mind a...    buddhism
# 8      the buddha  our lord  brings comfort to the we...    buddhism
# ...                                                  ...         ...
# 28105      and the spirit and the bride say  come  an...  christians
# 28107      for i testify unto every man that heareth ...  christians
# 28108  out of the holy city  and from the things whic...  christians
# 28110      he which testifieth these things saith  su...  christians
# 28114      the grace of our lord jesus christ be with...  christians
#
#        word_count
# 1               8
# 4              12
# 5              13
# 6              12
# 8              10
# ...           ...
# ...

# %%
data.drop(['word_count'],axis=1,inplace=True)
data
# Out:
# /Users/ravitiwari/miniforge3/envs/tf/lib/python3.9/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                     text       label
# 1      compiled from ancient records by paul carus in...    buddhism
# 4      rejoice at the glad tidings  the buddha  our l...    buddhism
# 5      root of all evil  he has shown us the way of s...    buddhism
# 6      the buddha dispels the illusions of our mind a...    buddhism
# 8      the buddha  our lord  brings comfort to the we...    buddhism
# ...                                                  ...         ...
# 28105      and the spirit and the bride say  come  an...  christians
# 28107      for i testify unto every man that heareth ...  christians
# ...

# %%
data.to_csv('religion_data.csv')

# %%
l=[
    "I would rather stand with God and be judged by the world, than stand with the world and be judged by God",
    "You’ve got voices pulling you in all different directions. There’s only one voice that matters",
    "Lord we need a generation of believers who are not ashamed of the gospel. We need an army of believers, Lord that hate to be lukewarm. And will stand on your word above all else raise them up, Lord raise them up",
    "What are you living for? I resolve to give God everything I’ve got, then I’ll leave the results up to Him. I want to know if you’ll join me",
    "When all you see is your pain, you lose sight of me",
    "What if God’s love is like the sun, constant and unchanging. What if you wake up some day and realize nothing can take that away.",
    "It’s time to rise up and answer the call that God has given to you and to say I will. I will. I will!",
    "Well, people aren’t gonna accept us for our faith. But it’s okay. We have to love and serve them anyways. And I’m talking compassion, forgiveness. I mean if we don’t, what’s gonna attract them to God?",
    "God’s good all the time. And all the time, God is good.",
    "In his time and in his way, God always keeps his promises",
    "There is a God who knows exactly what you’re worth",
    "I’m asking you to stand up, to make a decision, to change, to forgive, and to be forgiven",
    "Faith is the only true shelter",
    "I swore an oath as a Christian… to care for the least of these",
    "The truth of God’s love is not that he allows bad things to happen. It’s His promise that He’ll be here with us when they do.",
    "Jesus said, “Behold, the Kingdom of God is within you. If with all your hearts, you truly seek me, you shall ever surely find me.” If you commit yourself to the love of Christ, then that is how you run a straight race.",
    "Show me a Catholic, and I'll show you a junkie",
    "I was born a Catholic and now I'm a lapsed Catholic. I'm something but I'm not a believer any more.",
    "He hates God. He is repulsed by all things Christian. But these things do not kill him, no. They only fill him with a rage",
    "Life is precious, especially if you're a Christian and only allowed to have one",
    "We bet that there is a God",
    "Do you think people like the Christians hire us to invite us to their dinner parties? It's our job to clean up their royal messes",
    "Ohh Jesus!!",
    "Holy Fucking Jesus"
]

# %%
new_data=pd.DataFrame(l)

# %%
new_data.rename(columns={0:'tweet'},inplace=True)
new_data['label']='christians'
new_data
# Out:
#                                                 tweet       label
# 0   I would rather stand with God and be judged by...  christians
# 1   You’ve got voices pulling you in all different...  christians
# 2   Lord we need a generation of believers who are...  christians
# 3   What are you living for? I resolve to give God...  christians
# 4   When all you see is your pain, you lose sight ...  christians
# 5   What if God’s love is like the sun, constant a...  christians
# 6   It’s time to rise up and answer the call that ...  christians
# 7   Well, people aren’t gonna accept us for our fa...  christians
# 8   God’s good all the time. And all the time, God...  christians
# 9   In his time and in his way, God always keeps h...  christians
# 10  There is a God who knows exactly what you’re w...  christians
# 11  I’m asking you to stand up, to make a decision...  christians
# 12                     Faith is the only true shelter  christians
# ...

# %%
p=[
    "Conquer anger with non-anger. Conquer badness with goodness. Conquer meanness with generosity. Conquer dishonesty with truth"
    ,
    "Those who cling to perceptions and views wander the world offending people."
    ,
    "Drop by drop is the water pot filled. Likewise, the wise man, gathering it little by little, fills himself with good.",

    "I will not look at another’s bowl intent on finding fault: a training to be observed.",

    "Let none find fault with others; let none see the omissions and commissions of others. But let one see one’s own acts, done and undone."
,
    "Should a person do good, let him do it again and again. Let him find pleasure therein, for blissful is the accumulation of good."
,
    "May all beings have happy minds."
,
    "Delight in heedfulness! Guard well your thoughts!"
,
    "Should you find a wise critic to point out your faults, follow him as you would a guide to hidden treasure."
,
    "Should a seeker not find a companion who is better or equal, let them resolutely pursue a solitary course."
,
    "In whom there is no sympathy for living beings: know him as an outcast."
,
    "Hatred is never appeased by hatred in this world. By non-hatred alone is hatred appeased. This is a law eternal."
,
    "Live with no sense of ‘mine,’ not forming attachment to experiences."
,
    "Better it is to live one day seeing the rise and fall of things than to live a hundred years without ever seeing the rise and fall of things."
,
    "One is not called noble who harms living beings. By not harming living beings one is called noble."
,
    "If a man going down into a river, swollen and swiftly flowing, is carried away by the current — how can he help others across?"
,
    "All conditioned things are impermanent—when one sees this with wisdom, one turns away from suffering."
,
    "Ardently do today what must be done. Who knows? Tomorrow, death comes."
,
    "The world is afflicted by death and decay. But the wise do not grieve, having realized the nature of the world."
,
    "Resolutely train yourself to attain peace."
,
    "To support mother and father, to cherish wife and children, and to be engaged in peaceful occupation — this is the greatest blessing."
,
    "All tremble at violence; all fear death. Putting oneself in the place of another, one should not kill nor cause another to kill."
,
    "They blame those who remain silent, they blame those who speak much, they blame those who speak in moderation. There is none in the world who is not blamed."
,
    "Just as the great ocean has one taste, the taste of salt, so also this teaching and discipline has one taste, the taste of liberation."
,
    "If with a pure mind a person speaks or acts, happiness follows them like a never-departing shadow."
,
    "As an elephant in the battlefield withstands arrows shot from bows all around, even so shall I endure abuse."
,
    "The one in whom no longer exist the craving and thirst that perpetuate becoming; how could you track that Awakened one, trackless, and of limitless range."
]

# %%
new_data1=pd.DataFrame(p)

# %%
new_data1.rename(columns={0:'tweet'},inplace=True)
new_data1['label']='buddhism'
new_data1
# Out:
#                                                 tweet     label
# 0   Conquer anger with non-anger. Conquer badness ...  buddhism
# 1   Those who cling to perceptions and views wande...  buddhism
# 2   Drop by drop is the water pot filled. Likewise...  buddhism
# 3   I will not look at another’s bowl intent on fi...  buddhism
# 4   Let none find fault with others; let none see ...  buddhism
# 5   Should a person do good, let him do it again a...  buddhism
# 6                    May all beings have happy minds.  buddhism
# 7   Delight in heedfulness! Guard well your thoughts!  buddhism
# 8   Should you find a wise critic to point out you...  buddhism
# 9   Should a seeker not find a companion who is be...  buddhism
# 10  In whom there is no sympathy for living beings...  buddhism
# 11  Hatred is never appeased by hatred in this wor...  buddhism
# 12  Live with no sense of ‘mine,’ not forming atta...  buddhism
# 13  Better it is to live one day seeing the rise a...  buddhism
# ...

# %%
k=[
    "Love means never having to say you're sorry.",
    "They may take our lives, but they'll never take our freedom!",
    "They call me Mister Tibbs!",
    "When you realize you want to spend the rest of your life with somebody, you want the rest of your life to start as soon as possible.",
    "If you let my daughter go now, that'll be the end of it. I will not look for you, I will not pursue you. But if you don't, I will look for you, I will find you, and I will kill you",
    "You complete me.",
    "I drink your milkshake!",
    "Get your stinking paws off me, you damned dirty ape!",
    "You make me want to be a better man",
    "Chewie, we're home.",
    "Forget it, Jake. It's Chinatown.",
    "These go to eleven.",
    "I'm walking here! I'm walking here!",
    "It was Beauty killed the Beast.",
    "I'm just one stomach flu away from my goal weight.",
    "They call it a Royale with cheese",
    "Magic Mirror on the wall, who is the fairest one of all?",
    "Just when I thought I was out, they pull me back in",
    "Nobody's perfect.",
    "Wax on, wax off.",
    "You ain't heard nothin' yet!",
    "Gentlemen, you can't fight in here! This is the war room!",
    "I don't want to survive. I want to live",
    "Elementary, my dear Watson",
    "That'll do, pig. That'll do",
    "I wish I knew how to quit you"
]

# %%
new_data2=pd.DataFrame(k)

# %%
new_data2.rename(columns={0:'tweet'},inplace=True)
new_data2['label']='normal'
new_data2
# Out:
#                                                 tweet   label
# 0        Love means never having to say you're sorry.  normal
# 1   They may take our lives, but they'll never tak...  normal
# 2                          They call me Mister Tibbs!  normal
# 3   When you realize you want to spend the rest of...  normal
# 4   If you let my daughter go now, that'll be the ...  normal
# 5                                    You complete me.  normal
# 6                             I drink your milkshake!  normal
# 7   Get your stinking paws off me, you damned dirt...  normal
# 8                 You make me want to be a better man  normal
# 9                                 Chewie, we're home.  normal
# 10                   Forget it, Jake. It's Chinatown.  normal
# 11                                These go to eleven.  normal
# 12                I'm walking here! I'm walking here!  normal
# 13                    It was Beauty killed the Beast.  normal
# ...

# %%
data=pd.concat([new_data,new_data1,new_data2],ignore_index=True)
data
# Out:
#                                                 tweet       label
# 0   I would rather stand with God and be judged by...  christians
# 1   You’ve got voices pulling you in all different...  christians
# 2   Lord we need a generation of believers who are...  christians
# 3   What are you living for? I resolve to give God...  christians
# 4   When all you see is your pain, you lose sight ...  christians
# ..                                                ...         ...
# 72  Gentlemen, you can't fight in here! This is th...      normal
# 73            I don't want to survive. I want to live      normal
# 74                         Elementary, my dear Watson      normal
# 75                        That'll do, pig. That'll do      normal
# 76                      I wish I knew how to quit you      normal
#
# [77 rows x 2 columns]

# %%
data.to_csv("sample_religion_data.csv")
